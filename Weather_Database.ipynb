# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 625

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7a2215a6103eb084a89357ccde40a20d

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#for i, item in enumerate(list):
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]       
    except (KeyError):
        print("City not found. Skipping...")
        continue 
    try:
        city_rain = city_weather["rain"]["1h"]
    except (KeyError):
        print("No rain")
        city_rain = 0
        pass
    try:
        city_snow = city_weather["snow"]["1h"]
    except (KeyError):
        print("No snow")
        city_snow = 0
        pass
    
    print("Good data for "+city)
    # Append the city information into city_data list.
    city_data.append({"City": city.title(),
                      "Lat": city_lat,
                      "Lng": city_lng,
                      "Max Temp": city_max_temp,
                      "Humidity": city_humidity,
                      "Wind Speed": city_wind,
                      "Country": city_country,
                      "Current Desc": city_desc,
                      "Rain": city_rain,
                      "Snow": city_snow})           
            
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lagoa
# No rain
# No snow
# Good data for lagoa
# Processing Record 2 of Set 1 | muros
# No rain
# No snow
# Good data for muros
# Processing Record 3 of Set 1 | ahuimanu
# No rain
# No snow
# Good data for ahuimanu
# Processing Record 4 of Set 1 | tuktoyaktuk
# No rain
# No snow
# Good data for tuktoyaktuk
# Processing Record 5 of Set 1 | saint-augustin
# No rain
# No snow
# Good data for saint-augustin
# Processing Record 6 of Set 1 | ushuaia
# No rain
# No snow
# Good data for ushuaia
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 1 | marsa matruh
# No rain
# No snow
# Good data for marsa matruh
# Processing Record 10 of Set 1 | bluff
# No rain
# No snow
# Good data for bluff
# Processing Record 11 of Set 1 | kolomna
# No rain
# No snow
# Good data for kolomna
# Processing Record 12 of Set 1 | hofn
# No snow
# Good data for hofn
# Processing Record 13 of Set 1 | severo-kurilsk
# No rain
# No snow
# Good data for severo-kurilsk
# Processing Record 14 of Set 1 | sayyan
# No snow
# Good data for sayyan
# Processing Record 15 of Set 1 | nikolskoye
# No rain
# No snow
# Good data for nikolskoye
# Processing Record 16 of Set 1 | akyab
# No snow
# Good data for akyab
# Processing Record 17 of Set 1 | asau
# No snow
# Good data for asau
# Processing Record 18 of Set 1 | victoria
# No rain
# No snow
# Good data for victoria
# Processing Record 19 of Set 1 | assiniboia
# No rain
# No snow
# Good data for assiniboia
# Processing Record 20 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 1 | bengkulu
# No rain
# No snow
# Good data for bengkulu
# Processing Record 22 of Set 1 | cape town
# No rain
# No snow
# Good data for cape town
# Processing Record 23 of Set 1 | busselton
# No snow
# Good data for busselton
# Processing Record 24 of Set 1 | vao
# No rain
# No snow
# Good data for vao
# Processing Record 25 of Set 1 | kodiak
# No rain
# No snow
# Good data for kodiak
# Processing Record 26 of Set 1 | dongli
# No rain
# No snow
# Good data for dongli
# Processing Record 27 of Set 1 | provideniya
# No rain
# No snow
# Good data for provideniya
# Processing Record 28 of Set 1 | wadi maliz
# No rain
# No snow
# Good data for wadi maliz
# Processing Record 29 of Set 1 | rikitea
# No rain
# No snow
# Good data for rikitea
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | tasiilaq
# No rain
# No snow
# Good data for tasiilaq
# Processing Record 32 of Set 1 | mahebourg
# No rain
# No snow
# Good data for mahebourg
# Processing Record 33 of Set 1 | hermanus
# No rain
# No snow
# Good data for hermanus
# Processing Record 34 of Set 1 | synya
# No rain
# No snow
# Good data for synya
# Processing Record 35 of Set 1 | cidreira
# No rain
# No snow
# Good data for cidreira
# Processing Record 36 of Set 1 | saint-philippe
# No snow
# Good data for saint-philippe
# Processing Record 37 of Set 1 | moose factory
# No rain
# No snow
# Good data for moose factory
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | arlit
# No rain
# No snow
# Good data for arlit
# Processing Record 40 of Set 1 | margate
# No rain
# No snow
# Good data for margate
# Processing Record 41 of Set 1 | necochea
# No rain
# No snow
# Good data for necochea
# Processing Record 42 of Set 1 | punta arenas
# No rain
# No snow
# Good data for punta arenas
# Processing Record 43 of Set 1 | zhanaozen
# No rain
# No snow
# Good data for zhanaozen
# Processing Record 44 of Set 1 | green river
# No rain
# No snow
# Good data for green river
# Processing Record 45 of Set 1 | mar del plata
# No rain
# No snow
# Good data for mar del plata
# Processing Record 46 of Set 1 | pangkalanbuun
# No rain
# No snow
# Good data for pangkalanbuun
# Processing Record 47 of Set 1 | lompoc
# No rain
# No snow
# Good data for lompoc
# Processing Record 48 of Set 1 | khatanga
# No rain
# No snow
# Good data for khatanga
# Processing Record 49 of Set 1 | shanghai
# No snow
# Good data for shanghai
# Processing Record 50 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 2 | yellowknife
# No rain
# No snow
# Good data for yellowknife
# Processing Record 2 of Set 2 | chapais
# No rain
# No snow
# Good data for chapais
# Processing Record 3 of Set 2 | san quintin
# No snow
# Good data for san quintin
# Processing Record 4 of Set 2 | kargopol
# No rain
# No snow
# Good data for kargopol
# Processing Record 5 of Set 2 | calbuco
# No rain
# No snow
# Good data for calbuco
# Processing Record 6 of Set 2 | albany
# No rain
# No snow
# Good data for albany
# Processing Record 7 of Set 2 | phuket
# No rain
# No snow
# Good data for phuket
# Processing Record 8 of Set 2 | plettenberg bay
# No rain
# No snow
# Good data for plettenberg bay
# Processing Record 9 of Set 2 | avarua
# No rain
# No snow
# Good data for avarua
# Processing Record 10 of Set 2 | sao joao da barra
# No rain
# No snow
# Good data for sao joao da barra
# Processing Record 11 of Set 2 | constitucion
# No rain
# No snow
# Good data for constitucion
# Processing Record 12 of Set 2 | kaoma
# No rain
# No snow
# Good data for kaoma
# Processing Record 13 of Set 2 | carnarvon
# No rain
# No snow
# Good data for carnarvon
# Processing Record 14 of Set 2 | bubaque
# No snow
# Good data for bubaque
# Processing Record 15 of Set 2 | praia
# No rain
# No snow
# Good data for praia
# Processing Record 16 of Set 2 | cabedelo
# No rain
# No snow
# Good data for cabedelo
# Processing Record 17 of Set 2 | monrovia
# No rain
# No snow
# Good data for monrovia
# Processing Record 18 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 2 | bethel
# No rain
# No snow
# Good data for bethel
# Processing Record 20 of Set 2 | waingapu
# No rain
# No snow
# Good data for waingapu
# Processing Record 21 of Set 2 | mataura
# No rain
# No snow
# Good data for mataura
# Processing Record 22 of Set 2 | tsumeb
# No rain
# No snow
# Good data for tsumeb
# Processing Record 23 of Set 2 | colesberg
# No rain
# No snow
# Good data for colesberg
# Processing Record 24 of Set 2 | chokurdakh
# No rain
# No snow
# Good data for chokurdakh
# Processing Record 25 of Set 2 | butaritari
# No snow
# Good data for butaritari
# Processing Record 26 of Set 2 | aswan
# No rain
# No snow
# Good data for aswan
# Processing Record 27 of Set 2 | khorixas
# No rain
# No snow
# Good data for khorixas
# Processing Record 28 of Set 2 | ialibu
# No rain
# No snow
# Good data for ialibu
# Processing Record 29 of Set 2 | amuntai
# No rain
# No snow
# Good data for amuntai
# Processing Record 30 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 2 | dikson
# No rain
# No snow
# Good data for dikson
# Processing Record 32 of Set 2 | marzuq
# No rain
# No snow
# Good data for marzuq
# Processing Record 33 of Set 2 | tanout
# No snow
# Good data for tanout
# Processing Record 34 of Set 2 | dongsheng
# No rain
# No snow
# Good data for dongsheng
# Processing Record 35 of Set 2 | bakchar
# No rain
# No snow
# Good data for bakchar
# Processing Record 36 of Set 2 | tautira
# No rain
# No snow
# Good data for tautira
# Processing Record 37 of Set 2 | ayagoz
# No rain
# No snow
# Good data for ayagoz
# Processing Record 38 of Set 2 | vanimo
# No snow
# Good data for vanimo
# Processing Record 39 of Set 2 | oranjemund
# No rain
# No snow
# Good data for oranjemund
# Processing Record 40 of Set 2 | dalvik
# No rain
# No snow
# Good data for dalvik
# Processing Record 41 of Set 2 | birao
# No snow
# Good data for birao
# Processing Record 42 of Set 2 | aripuana
# No rain
# No snow
# Good data for aripuana
# Processing Record 43 of Set 2 | kapaa
# No rain
# No snow
# Good data for kapaa
# Processing Record 44 of Set 2 | miri
# No rain
# No snow
# Good data for miri
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | lebu
# No rain
# No snow
# Good data for lebu
# Processing Record 47 of Set 2 | vaini
# No rain
# No snow
# Good data for vaini
# Processing Record 48 of Set 2 | hofu
# No rain
# No snow
# Good data for hofu
# Processing Record 49 of Set 2 | chapada dos guimaraes
# No rain
# No snow
# Good data for chapada dos guimaraes
# Processing Record 50 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 3 | la ronge
# No rain
# No snow
# Good data for la ronge
# Processing Record 2 of Set 3 | gamba
# No rain
# No snow
# Good data for gamba
# Processing Record 3 of Set 3 | ribeira grande
# No rain
# No snow
# Good data for ribeira grande
# Processing Record 4 of Set 3 | port hedland
# No rain
# No snow
# Good data for port hedland
# Processing Record 5 of Set 3 | georgetown
# No rain
# No snow
# Good data for georgetown
# Processing Record 6 of Set 3 | kahului
# No rain
# No snow
# Good data for kahului
# Processing Record 7 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 3 | davila
# No rain
# No snow
# Good data for davila
# Processing Record 9 of Set 3 | palmer
# No rain
# No snow
# Good data for palmer
# Processing Record 10 of Set 3 | deseronto
# No snow
# Good data for deseronto
# Processing Record 11 of Set 3 | qaanaaq
# No rain
# No snow
# Good data for qaanaaq
# Processing Record 12 of Set 3 | kitob
# No rain
# No snow
# Good data for kitob
# Processing Record 13 of Set 3 | hilo
# No snow
# Good data for hilo
# Processing Record 14 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 15 of Set 3 | kaifeng
# No rain
# No snow
# Good data for kaifeng
# Processing Record 16 of Set 3 | shaoxing
# No rain
# No snow
# Good data for shaoxing
# Processing Record 17 of Set 3 | yaan
# No snow
# Good data for yaan
# Processing Record 18 of Set 3 | kattivakkam
# No rain
# No snow
# Good data for kattivakkam
# Processing Record 19 of Set 3 | sabha
# No rain
# No snow
# Good data for sabha
# Processing Record 20 of Set 3 | hambantota
# No rain
# No snow
# Good data for hambantota
# Processing Record 21 of Set 3 | chuy
# No rain
# No snow
# Good data for chuy
# Processing Record 22 of Set 3 | ranong
# No snow
# Good data for ranong
# Processing Record 23 of Set 3 | puerto narino
# No rain
# No snow
# Good data for puerto narino
# Processing Record 24 of Set 3 | gulu
# No rain
# No snow
# Good data for gulu
# Processing Record 25 of Set 3 | bud
# No rain
# No snow
# Good data for bud
# Processing Record 26 of Set 3 | port alfred
# No rain
# No snow
# Good data for port alfred
# Processing Record 27 of Set 3 | kokopo
# No snow
# Good data for kokopo
# Processing Record 28 of Set 3 | dingle
# No snow
# Good data for dingle
# Processing Record 29 of Set 3 | port-gentil
# No rain
# No snow
# Good data for port-gentil
# Processing Record 30 of Set 3 | colares
# No rain
# No snow
# Good data for colares
# Processing Record 31 of Set 3 | felanitx
# No rain
# No snow
# Good data for felanitx
# Processing Record 32 of Set 3 | elizabeth city
# No rain
# No snow
# Good data for elizabeth city
# Processing Record 33 of Set 3 | zambezi
# No rain
# No snow
# Good data for zambezi
# Processing Record 34 of Set 3 | fairbanks
# No rain
# No snow
# Good data for fairbanks
# Processing Record 35 of Set 3 | homer
# No rain
# No snow
# Good data for homer
# Processing Record 36 of Set 3 | berlevag
# No rain
# No snow
# Good data for berlevag
# Processing Record 37 of Set 3 | guia de isora
# No rain
# No snow
# Good data for guia de isora
# Processing Record 38 of Set 3 | fortuna
# No rain
# No snow
# Good data for fortuna
# Processing Record 39 of Set 3 | narsaq
# No rain
# No snow
# Good data for narsaq
# Processing Record 40 of Set 3 | jiangkou
# No rain
# No snow
# Good data for jiangkou
# Processing Record 41 of Set 3 | winnemucca
# No rain
# No snow
# Good data for winnemucca
# Processing Record 42 of Set 3 | batticaloa
# No rain
# No snow
# Good data for batticaloa
# Processing Record 43 of Set 3 | marica
# No rain
# No snow
# Good data for marica
# Processing Record 44 of Set 3 | wokha
# No snow
# Good data for wokha
# Processing Record 45 of Set 3 | wattegama
# No rain
# No snow
# Good data for wattegama
# Processing Record 46 of Set 3 | port elizabeth
# No rain
# No snow
# Good data for port elizabeth
# Processing Record 47 of Set 3 | tura
# No snow
# Good data for tura
# Processing Record 48 of Set 3 | saldanha
# No rain
# No snow
# Good data for saldanha
# Processing Record 49 of Set 3 | new norfolk
# No snow
# Good data for new norfolk
# Processing Record 50 of Set 3 | praia da vitoria
# No rain
# No snow
# Good data for praia da vitoria
# Processing Record 1 of Set 4 | cabra
# No rain
# No snow
# Good data for cabra
# Processing Record 2 of Set 4 | great yarmouth
# No rain
# No snow
# Good data for great yarmouth
# Processing Record 3 of Set 4 | evensk
# No snow
# Good data for evensk
# Processing Record 4 of Set 4 | atuona
# No rain
# No snow
# Good data for atuona
# Processing Record 5 of Set 4 | maceio
# No rain
# No snow
# Good data for maceio
# Processing Record 6 of Set 4 | saint-paul
# No rain
# No snow
# Good data for saint-paul
# Processing Record 7 of Set 4 | saskylakh
# No rain
# No snow
# Good data for saskylakh
# Processing Record 8 of Set 4 | caravelas
# No rain
# No snow
# Good data for caravelas
# Processing Record 9 of Set 4 | lamar
# No rain
# No snow
# Good data for lamar
# Processing Record 10 of Set 4 | hobyo
# No rain
# No snow
# Good data for hobyo
# Processing Record 11 of Set 4 | aleksandrovsk-sakhalinskiy
# No rain
# No snow
# Good data for aleksandrovsk-sakhalinskiy
# Processing Record 12 of Set 4 | toora-khem
# No rain
# No snow
# Good data for toora-khem
# Processing Record 13 of Set 4 | hobart
# No rain
# No snow
# Good data for hobart
# Processing Record 14 of Set 4 | souillac
# No rain
# No snow
# Good data for souillac
# Processing Record 15 of Set 4 | zhoucheng
# No rain
# No snow
# Good data for zhoucheng
# Processing Record 16 of Set 4 | castro
# No rain
# No snow
# Good data for castro
# Processing Record 17 of Set 4 | villazon
# No rain
# No snow
# Good data for villazon
# Processing Record 18 of Set 4 | salalah
# No rain
# No snow
# Good data for salalah
# Processing Record 19 of Set 4 | rio gallegos
# No rain
# No snow
# Good data for rio gallegos
# Processing Record 20 of Set 4 | xichang
# No rain
# No snow
# Good data for xichang
# Processing Record 21 of Set 4 | floro
# No rain
# No snow
# Good data for floro
# Processing Record 22 of Set 4 | nanfeng
# No rain
# No snow
# Good data for nanfeng
# Processing Record 23 of Set 4 | choma
# No rain
# No snow
# Good data for choma
# Processing Record 24 of Set 4 | santa luzia
# No rain
# No snow
# Good data for santa luzia
# Processing Record 25 of Set 4 | hays
# No rain
# No snow
# Good data for hays
# Processing Record 26 of Set 4 | sarangani
# No rain
# No snow
# Good data for sarangani
# Processing Record 27 of Set 4 | kidal
# No rain
# No snow
# Good data for kidal
# Processing Record 28 of Set 4 | padang
# No snow
# Good data for padang
# Processing Record 29 of Set 4 | denpasar
# No rain
# No snow
# Good data for denpasar
# Processing Record 30 of Set 4 | lorengau
# No rain
# No snow
# Good data for lorengau
# Processing Record 31 of Set 4 | debno
# No rain
# No snow
# Good data for debno
# Processing Record 32 of Set 4 | port lincoln
# No rain
# No snow
# Good data for port lincoln
# Processing Record 33 of Set 4 | bredasdorp
# No rain
# No snow
# Good data for bredasdorp
# Processing Record 34 of Set 4 | bambous virieux
# No rain
# No snow
# Good data for bambous virieux
# Processing Record 35 of Set 4 | olinda
# No rain
# No snow
# Good data for olinda
# Processing Record 36 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 4 | upernavik
# No rain
# No snow
# Good data for upernavik
# Processing Record 38 of Set 4 | santander
# No rain
# No snow
# Good data for santander
# Processing Record 39 of Set 4 | reshetylivka
# No rain
# No snow
# Good data for reshetylivka
# Processing Record 40 of Set 4 | salamiyah
# No rain
# No snow
# Good data for salamiyah
# Processing Record 41 of Set 4 | melito di porto salvo
# No rain
# No snow
# Good data for melito di porto salvo
# Processing Record 42 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 4 | wewak
# No snow
# Good data for wewak
# Processing Record 44 of Set 4 | mwene-ditu
# No rain
# No snow
# Good data for mwene-ditu
# Processing Record 45 of Set 4 | tsienyane
# City not found. Skipping...
# Processing Record 46 of Set 4 | zhezkazgan
# No rain
# No snow
# Good data for zhezkazgan
# Processing Record 47 of Set 4 | shitanjing
# No rain
# No snow
# Good data for shitanjing
# Processing Record 48 of Set 4 | havre-saint-pierre
# No rain
# No snow
# Good data for havre-saint-pierre
# Processing Record 49 of Set 4 | canas
# No rain
# No snow
# Good data for canas
# Processing Record 50 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 5 | pocos de caldas
# No rain
# No snow
# Good data for pocos de caldas
# Processing Record 2 of Set 5 | coquimbo
# No rain
# No snow
# Good data for coquimbo
# Processing Record 3 of Set 5 | narrabri
# No rain
# No snow
# Good data for narrabri
# Processing Record 4 of Set 5 | clyde river
# No rain
# No snow
# Good data for clyde river
# Processing Record 5 of Set 5 | deputatskiy
# No rain
# No snow
# Good data for deputatskiy
# Processing Record 6 of Set 5 | barrow
# No rain
# No snow
# Good data for barrow
# Processing Record 7 of Set 5 | east london
# No rain
# No snow
# Good data for east london
# Processing Record 8 of Set 5 | almeirim
# No rain
# No snow
# Good data for almeirim
# Processing Record 9 of Set 5 | esperantinopolis
# No rain
# No snow
# Good data for esperantinopolis
# Processing Record 10 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 5 | baker city
# No rain
# No snow
# Good data for baker city
# Processing Record 12 of Set 5 | namatanai
# No snow
# Good data for namatanai
# Processing Record 13 of Set 5 | bemidji
# No rain
# No snow
# Good data for bemidji
# Processing Record 14 of Set 5 | dawlatabad
# No rain
# No snow
# Good data for dawlatabad
# Processing Record 15 of Set 5 | swan river
# No rain
# No snow
# Good data for swan river
# Processing Record 16 of Set 5 | pevek
# No rain
# No snow
# Good data for pevek
# Processing Record 17 of Set 5 | fukue
# No rain
# No snow
# Good data for fukue
# Processing Record 18 of Set 5 | thompson
# No rain
# No snow
# Good data for thompson
# Processing Record 19 of Set 5 | puerto ayora
# No rain
# No snow
# Good data for puerto ayora
# Processing Record 20 of Set 5 | broken hill
# No rain
# No snow
# Good data for broken hill
# Processing Record 21 of Set 5 | hoquiam
# No rain
# No snow
# Good data for hoquiam
# Processing Record 22 of Set 5 | camacha
# No rain
# No snow
# Good data for camacha
# Processing Record 23 of Set 5 | bridgton
# No rain
# No snow
# Good data for bridgton
# Processing Record 24 of Set 5 | oussouye
# No rain
# No snow
# Good data for oussouye
# Processing Record 25 of Set 5 | geraldton
# No rain
# No snow
# Good data for geraldton
# Processing Record 26 of Set 5 | stromness
# No rain
# No snow
# Good data for stromness
# Processing Record 27 of Set 5 | kavieng
# No rain
# No snow
# Good data for kavieng
# Processing Record 28 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 5 | bandarbeyla
# No rain
# No snow
# Good data for bandarbeyla
# Processing Record 30 of Set 5 | francistown
# No rain
# No snow
# Good data for francistown
# Processing Record 31 of Set 5 | kenora
# No rain
# No snow
# Good data for kenora
# Processing Record 32 of Set 5 | sibolga
# No snow
# Good data for sibolga
# Processing Record 33 of Set 5 | kudahuvadhoo
# No rain
# No snow
# Good data for kudahuvadhoo
# Processing Record 34 of Set 5 | rock sound
# No snow
# Good data for rock sound
# Processing Record 35 of Set 5 | braslav
# City not found. Skipping...
# Processing Record 36 of Set 5 | touros
# No rain
# No snow
# Good data for touros
# Processing Record 37 of Set 5 | katsuura
# No rain
# No snow
# Good data for katsuura
# Processing Record 38 of Set 5 | mitsamiouli
# No rain
# No snow
# Good data for mitsamiouli
# Processing Record 39 of Set 5 | ontario
# No rain
# No snow
# Good data for ontario
# Processing Record 40 of Set 5 | ocos
# No rain
# No snow
# Good data for ocos
# Processing Record 41 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 5 | kaitangata
# No rain
# No snow
# Good data for kaitangata
# Processing Record 43 of Set 5 | torbay
# No rain
# No snow
# Good data for torbay
# Processing Record 44 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 45 of Set 5 | harboore
# No rain
# No snow
# Good data for harboore
# Processing Record 46 of Set 5 | boa vista
# No rain
# No snow
# Good data for boa vista
# Processing Record 47 of Set 5 | tucurui
# No rain
# No snow
# Good data for tucurui
# Processing Record 48 of Set 5 | kurchum
# No rain
# No snow
# Good data for kurchum
# Processing Record 49 of Set 5 | mogadishu
# No snow
# Good data for mogadishu
# Processing Record 50 of Set 5 | takoradi
# No rain
# No snow
# Good data for takoradi
# Processing Record 1 of Set 6 | nyaunglebin
# No snow
# Good data for nyaunglebin
# Processing Record 2 of Set 6 | freiburg
# No rain
# No snow
# Good data for freiburg
# Processing Record 3 of Set 6 | yuancheng
# No rain
# No snow
# Good data for yuancheng
# Processing Record 4 of Set 6 | lavrentiya
# No rain
# No snow
# Good data for lavrentiya
# Processing Record 5 of Set 6 | buala
# No snow
# Good data for buala
# Processing Record 6 of Set 6 | esperance
# No rain
# No snow
# Good data for esperance
# Processing Record 7 of Set 6 | angoche
# No rain
# No snow
# Good data for angoche
# Processing Record 8 of Set 6 | buchanan
# No rain
# No snow
# Good data for buchanan
# Processing Record 9 of Set 6 | aljezur
# No rain
# No snow
# Good data for aljezur
# Processing Record 10 of Set 6 | los llanos de aridane
# No rain
# No snow
# Good data for los llanos de aridane
# Processing Record 11 of Set 6 | beringovskiy
# No rain
# No snow
# Good data for beringovskiy
# Processing Record 12 of Set 6 | yuxia
# No rain
# No snow
# Good data for yuxia
# Processing Record 13 of Set 6 | kampot
# No rain
# No snow
# Good data for kampot
# Processing Record 14 of Set 6 | mao
# No rain
# No snow
# Good data for mao
# Processing Record 15 of Set 6 | arraial do cabo
# No rain
# No snow
# Good data for arraial do cabo
# Processing Record 16 of Set 6 | taoudenni
# No rain
# No snow
# Good data for taoudenni
# Processing Record 17 of Set 6 | novikovo
# No rain
# No snow
# Good data for novikovo
# Processing Record 18 of Set 6 | airai
# No rain
# No snow
# Good data for airai
# Processing Record 19 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 20 of Set 6 | goma
# No snow
# Good data for goma
# Processing Record 21 of Set 6 | aklavik
# No rain
# No snow
# Good data for aklavik
# Processing Record 22 of Set 6 | hithadhoo
# No rain
# No snow
# Good data for hithadhoo
# Processing Record 23 of Set 6 | sitka
# No rain
# No snow
# Good data for sitka
# Processing Record 24 of Set 6 | kununurra
# No rain
# No snow
# Good data for kununurra
# Processing Record 25 of Set 6 | rawson
# No rain
# No snow
# Good data for rawson
# Processing Record 26 of Set 6 | bobcaygeon
# No rain
# No snow
# Good data for bobcaygeon
# Processing Record 27 of Set 6 | atar
# No rain
# No snow
# Good data for atar
# Processing Record 28 of Set 6 | wanning
# No rain
# No snow
# Good data for wanning
# Processing Record 29 of Set 6 | tripoli
# No rain
# No snow
# Good data for tripoli
# Processing Record 30 of Set 6 | mudon
# No snow
# Good data for mudon
# Processing Record 31 of Set 6 | ode
# No snow
# Good data for ode
# Processing Record 32 of Set 6 | lyantonde
# No rain
# No snow
# Good data for lyantonde
# Processing Record 33 of Set 6 | faanui
# No rain
# No snow
# Good data for faanui
# Processing Record 34 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 6 | ampanihy
# No rain
# No snow
# Good data for ampanihy
# Processing Record 36 of Set 6 | naurskaya
# No rain
# No snow
# Good data for naurskaya
# Processing Record 37 of Set 6 | ambilobe
# No rain
# No snow
# Good data for ambilobe
# Processing Record 38 of Set 6 | harper
# No rain
# No snow
# Good data for harper
# Processing Record 39 of Set 6 | talnakh
# No rain
# No snow
# Good data for talnakh
# Processing Record 40 of Set 6 | severomuysk
# No rain
# No snow
# Good data for severomuysk
# Processing Record 41 of Set 6 | quatre cocos
# No rain
# No snow
# Good data for quatre cocos
# Processing Record 42 of Set 6 | ucluelet
# No rain
# No snow
# Good data for ucluelet
# Processing Record 43 of Set 6 | hualmay
# No rain
# No snow
# Good data for hualmay
# Processing Record 44 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 6 | saint george
# No rain
# No snow
# Good data for saint george
# Processing Record 47 of Set 6 | mumford
# No rain
# No snow
# Good data for mumford
# Processing Record 48 of Set 6 | kalmunai
# No rain
# No snow
# Good data for kalmunai
# Processing Record 49 of Set 6 | douentza
# No rain
# No snow
# Good data for douentza
# Processing Record 50 of Set 6 | college
# No rain
# No snow
# Good data for college
# Processing Record 1 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 7 | mbini
# No snow
# Good data for mbini
# Processing Record 3 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 4 of Set 7 | dunedin
# No rain
# No snow
# Good data for dunedin
# Processing Record 5 of Set 7 | acapulco
# No rain
# No snow
# Good data for acapulco
# Processing Record 6 of Set 7 | cherskiy
# No rain
# No snow
# Good data for cherskiy
# Processing Record 7 of Set 7 | daru
# No snow
# Good data for daru
# Processing Record 8 of Set 7 | charlestown
# No rain
# No snow
# Good data for charlestown
# Processing Record 9 of Set 7 | jamestown
# No rain
# No snow
# Good data for jamestown
# Processing Record 10 of Set 7 | nouadhibou
# No rain
# No snow
# Good data for nouadhibou
# Processing Record 11 of Set 7 | itarema
# No snow
# Good data for itarema
# Processing Record 12 of Set 7 | jahrom
# City not found. Skipping...
# Processing Record 13 of Set 7 | lar
# No snow
# Good data for lar
# Processing Record 14 of Set 7 | hurghada
# No rain
# No snow
# Good data for hurghada
# Processing Record 15 of Set 7 | mehamn
# No rain
# No snow
# Good data for mehamn
# Processing Record 16 of Set 7 | ponta do sol
# No rain
# No snow
# Good data for ponta do sol
# Processing Record 17 of Set 7 | hamilton
# No rain
# No snow
# Good data for hamilton
# Processing Record 18 of Set 7 | seoul
# No snow
# Good data for seoul
# Processing Record 19 of Set 7 | taos
# No rain
# No snow
# Good data for taos
# Processing Record 20 of Set 7 | abeche
# No rain
# No snow
# Good data for abeche
# Processing Record 21 of Set 7 | pangnirtung
# No rain
# No snow
# Good data for pangnirtung
# Processing Record 22 of Set 7 | san ramon
# No rain
# No snow
# Good data for san ramon
# Processing Record 23 of Set 7 | peterhead
# No rain
# No snow
# Good data for peterhead
# Processing Record 24 of Set 7 | alofi
# No rain
# No snow
# Good data for alofi
# Processing Record 25 of Set 7 | lakes entrance
# No snow
# Good data for lakes entrance
# Processing Record 26 of Set 7 | cockburn town
# No rain
# No snow
# Good data for cockburn town
# Processing Record 27 of Set 7 | gat
# No rain
# No snow
# Good data for gat
# Processing Record 28 of Set 7 | tshikapa
# No rain
# No snow
# Good data for tshikapa
# Processing Record 29 of Set 7 | vila
# No rain
# No snow
# Good data for vila
# Processing Record 30 of Set 7 | dire
# No snow
# Good data for dire
# Processing Record 31 of Set 7 | peniche
# No rain
# No snow
# Good data for peniche
# Processing Record 32 of Set 7 | timra
# No rain
# No snow
# Good data for timra
# Processing Record 33 of Set 7 | san ignacio de sabaneta
# City not found. Skipping...
# Processing Record 34 of Set 7 | pacific grove
# No rain
# No snow
# Good data for pacific grove
# Processing Record 35 of Set 7 | svistov
# City not found. Skipping...
# Processing Record 36 of Set 7 | sokoto
# No snow
# Good data for sokoto
# Processing Record 37 of Set 7 | itoman
# No rain
# No snow
# Good data for itoman
# Processing Record 38 of Set 7 | chita
# No rain
# No snow
# Good data for chita
# Processing Record 39 of Set 7 | bossangoa
# No snow
# Good data for bossangoa
# Processing Record 40 of Set 7 | bilibino
# No snow
# Good data for bilibino
# Processing Record 41 of Set 7 | bocaiuva
# No rain
# No snow
# Good data for bocaiuva
# Processing Record 42 of Set 7 | darhan
# No rain
# No snow
# Good data for darhan
# Processing Record 43 of Set 7 | andenes
# No rain
# No snow
# Good data for andenes
# Processing Record 44 of Set 7 | san cristobal
# No rain
# No snow
# Good data for san cristobal
# Processing Record 45 of Set 7 | yar-sale
# No snow
# Good data for yar-sale
# Processing Record 46 of Set 7 | ilulissat
# No rain
# No snow
# Good data for ilulissat
# Processing Record 47 of Set 7 | porto empedocle
# No rain
# No snow
# Good data for porto empedocle
# Processing Record 48 of Set 7 | pisco
# No rain
# No snow
# Good data for pisco
# Processing Record 49 of Set 7 | san patricio
# No rain
# No snow
# Good data for san patricio
# Processing Record 50 of Set 7 | dasoguz
# No rain
# No snow
# Good data for dasoguz
# Processing Record 1 of Set 8 | conde
# No rain
# No snow
# Good data for conde
# Processing Record 2 of Set 8 | mackay
# No rain
# No snow
# Good data for mackay
# Processing Record 3 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 8 | camopi
# No snow
# Good data for camopi
# Processing Record 5 of Set 8 | finschhafen
# No rain
# No snow
# Good data for finschhafen
# Processing Record 6 of Set 8 | sobolevo
# No rain
# No snow
# Good data for sobolevo
# Processing Record 7 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 8 | tiksi
# No rain
# No snow
# Good data for tiksi
# Processing Record 9 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 8 | chute-aux-outardes
# No rain
# No snow
# Good data for chute-aux-outardes
# Processing Record 11 of Set 8 | luwuk
# No rain
# No snow
# Good data for luwuk
# Processing Record 12 of Set 8 | puerto quijarro
# No rain
# No snow
# Good data for puerto quijarro
# Processing Record 13 of Set 8 | vidim
# No rain
# No snow
# Good data for vidim
# Processing Record 14 of Set 8 | chifeng
# No rain
# No snow
# Good data for chifeng
# Processing Record 15 of Set 8 | opuwo
# No rain
# No snow
# Good data for opuwo
# Processing Record 16 of Set 8 | baghdad
# No rain
# No snow
# Good data for baghdad
# Processing Record 17 of Set 8 | bac lieu
# No rain
# No snow
# Good data for bac lieu
# Processing Record 18 of Set 8 | milingimbi
# City not found. Skipping...
# Processing Record 19 of Set 8 | baile herculane
# No rain
# No snow
# Good data for baile herculane
# Processing Record 20 of Set 8 | hasaki
# No rain
# No snow
# Good data for hasaki
# Processing Record 21 of Set 8 | hami
# No rain
# No snow
# Good data for hami
# Processing Record 22 of Set 8 | road town
# No rain
# No snow
# Good data for road town
# Processing Record 23 of Set 8 | labuhan
# No rain
# No snow
# Good data for labuhan
# Processing Record 24 of Set 8 | klaksvik
# No rain
# No snow
# Good data for klaksvik
# Processing Record 25 of Set 8 | cintalapa
# No snow
# Good data for cintalapa
# Processing Record 26 of Set 8 | tabas
# No rain
# No snow
# Good data for tabas
# Processing Record 27 of Set 8 | pangody
# No snow
# Good data for pangody
# Processing Record 28 of Set 8 | faya
# No rain
# No snow
# Good data for faya
# Processing Record 29 of Set 8 | ketchikan
# No rain
# No snow
# Good data for ketchikan
# Processing Record 30 of Set 8 | ambanja
# No rain
# No snow
# Good data for ambanja
# Processing Record 31 of Set 8 | sindor
# No rain
# No snow
# Good data for sindor
# Processing Record 32 of Set 8 | geri
# No rain
# No snow
# Good data for geri
# Processing Record 33 of Set 8 | guerrero negro
# No rain
# No snow
# Good data for guerrero negro
# Processing Record 34 of Set 8 | rincon
# No rain
# No snow
# Good data for rincon
# Processing Record 35 of Set 8 | odweyne
# No rain
# No snow
# Good data for odweyne
# Processing Record 36 of Set 8 | matsanga
# City not found. Skipping...
# Processing Record 37 of Set 8 | tocopilla
# No rain
# No snow
# Good data for tocopilla
# Processing Record 38 of Set 8 | yining
# No rain
# No snow
# Good data for yining
# Processing Record 39 of Set 8 | port moresby
# No rain
# No snow
# Good data for port moresby
# Processing Record 40 of Set 8 | coihueco
# No rain
# No snow
# Good data for coihueco
# Processing Record 41 of Set 8 | nanortalik
# No snow
# Good data for nanortalik
# Processing Record 42 of Set 8 | bilma
# No rain
# No snow
# Good data for bilma
# Processing Record 43 of Set 8 | harbour breton
# No snow
# Good data for harbour breton
# Processing Record 44 of Set 8 | kurumkan
# No rain
# No snow
# Good data for kurumkan
# Processing Record 45 of Set 8 | la antigua
# No snow
# Good data for la antigua
# Processing Record 46 of Set 8 | jizan
# No rain
# No snow
# Good data for jizan
# Processing Record 47 of Set 8 | port blair
# No rain
# No snow
# Good data for port blair
# Processing Record 48 of Set 8 | iqaluit
# No rain
# No snow
# Good data for iqaluit
# Processing Record 49 of Set 8 | sao miguel do araguaia
# No rain
# No snow
# Good data for sao miguel do araguaia
# Processing Record 50 of Set 8 | zyryanka
# No rain
# No snow
# Good data for zyryanka
# Processing Record 1 of Set 9 | pafos
# No rain
# No snow
# Good data for pafos
# Processing Record 2 of Set 9 | komsomolskiy
# No rain
# No snow
# Good data for komsomolskiy
# Processing Record 3 of Set 9 | saryagash
# No rain
# No snow
# Good data for saryagash
# Processing Record 4 of Set 9 | tessalit
# No rain
# No snow
# Good data for tessalit
# Processing Record 5 of Set 9 | vila velha
# No rain
# No snow
# Good data for vila velha
# Processing Record 6 of Set 9 | bathsheba
# No rain
# No snow
# Good data for bathsheba
# Processing Record 7 of Set 9 | norman wells
# No rain
# No snow
# Good data for norman wells
# Processing Record 8 of Set 9 | portland
# No rain
# No snow
# Good data for portland
# Processing Record 9 of Set 9 | altay
# No rain
# No snow
# Good data for altay
# Processing Record 10 of Set 9 | buin
# No rain
# No snow
# Good data for buin
# Processing Record 11 of Set 9 | ostrovnoy
# No rain
# No snow
# Good data for ostrovnoy
# Processing Record 12 of Set 9 | iranshahr
# No rain
# No snow
# Good data for iranshahr
# Processing Record 13 of Set 9 | fort saint james
# No snow
# Good data for fort saint james
# Processing Record 14 of Set 9 | puerto madryn
# No rain
# No snow
# Good data for puerto madryn
# Processing Record 15 of Set 9 | norvenich
# No rain
# No snow
# Good data for norvenich
# Processing Record 16 of Set 9 | kudat
# No rain
# No snow
# Good data for kudat
# Processing Record 17 of Set 9 | ngaoundere
# No rain
# No snow
# Good data for ngaoundere
# Processing Record 18 of Set 9 | longyearbyen
# No rain
# No snow
# Good data for longyearbyen
# Processing Record 19 of Set 9 | pringsewu
# No rain
# No snow
# Good data for pringsewu
# Processing Record 20 of Set 9 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 21 of Set 9 | aykhal
# No rain
# No snow
# Good data for aykhal
# Processing Record 22 of Set 9 | vilyuysk
# No rain
# No snow
# Good data for vilyuysk
# Processing Record 23 of Set 9 | gazanjyk
# No rain
# No snow
# Good data for gazanjyk
# Processing Record 24 of Set 9 | shenjiamen
# No rain
# No snow
# Good data for shenjiamen
# Processing Record 25 of Set 9 | haileybury
# No rain
# No snow
# Good data for haileybury
# Processing Record 26 of Set 9 | jalu
# No rain
# No snow
# Good data for jalu
# Processing Record 27 of Set 9 | golden
# No rain
# No snow
# Good data for golden
# Processing Record 28 of Set 9 | liminangcong
# City not found. Skipping...
# Processing Record 29 of Set 9 | burica
# City not found. Skipping...
# Processing Record 30 of Set 9 | siderno
# No rain
# No snow
# Good data for siderno
# Processing Record 31 of Set 9 | kruisfontein
# No rain
# No snow
# Good data for kruisfontein
# Processing Record 32 of Set 9 | zhicheng
# No rain
# No snow
# Good data for zhicheng
# Processing Record 33 of Set 9 | nemuro
# No rain
# No snow
# Good data for nemuro
# Processing Record 34 of Set 9 | mirador
# No rain
# No snow
# Good data for mirador
# Processing Record 35 of Set 9 | iralaya
# No rain
# No snow
# Good data for iralaya
# Processing Record 36 of Set 9 | arrecife
# No rain
# No snow
# Good data for arrecife
# Processing Record 37 of Set 9 | te anau
# No rain
# No snow
# Good data for te anau
# Processing Record 38 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 9 | rabo de peixe
# No rain
# No snow
# Good data for rabo de peixe
# Processing Record 40 of Set 9 | sola
# No snow
# Good data for sola
# Processing Record 41 of Set 9 | kongoussi
# No snow
# Good data for kongoussi
# Processing Record 42 of Set 9 | bardiyah
# No rain
# No snow
# Good data for bardiyah
# Processing Record 43 of Set 9 | vardo
# No rain
# No snow
# Good data for vardo
# Processing Record 44 of Set 9 | meulaboh
# No rain
# No snow
# Good data for meulaboh
# Processing Record 45 of Set 9 | cap-aux-meules
# No rain
# No snow
# Good data for cap-aux-meules
# Processing Record 46 of Set 9 | timbiqui
# No rain
# No snow
# Good data for timbiqui
# Processing Record 47 of Set 9 | honningsvag
# No rain
# No snow
# Good data for honningsvag
# Processing Record 48 of Set 9 | grindavik
# No rain
# No snow
# Good data for grindavik
# Processing Record 49 of Set 9 | sokoni
# No rain
# No snow
# Good data for sokoni
# Processing Record 50 of Set 9 | batsfjord
# No rain
# No snow
# Good data for batsfjord
# Processing Record 1 of Set 10 | dalinghe
# City not found. Skipping...
# Processing Record 2 of Set 10 | zeya
# No rain
# No snow
# Good data for zeya
# Processing Record 3 of Set 10 | umm kaddadah
# No rain
# No snow
# Good data for umm kaddadah
# Processing Record 4 of Set 10 | lyngseidet
# No rain
# No snow
# Good data for lyngseidet
# Processing Record 5 of Set 10 | cabo san lucas
# No rain
# No snow
# Good data for cabo san lucas
# Processing Record 6 of Set 10 | manaure
# No rain
# No snow
# Good data for manaure
# Processing Record 7 of Set 10 | mount isa
# No rain
# No snow
# Good data for mount isa
# Processing Record 8 of Set 10 | porto tolle
# No rain
# No snow
# Good data for porto tolle
# Processing Record 9 of Set 10 | ambon
# No snow
# Good data for ambon
# Processing Record 10 of Set 10 | tatarsk
# No rain
# No snow
# Good data for tatarsk
# Processing Record 11 of Set 10 | salta
# No rain
# No snow
# Good data for salta
# Processing Record 12 of Set 10 | vostok
# No rain
# No snow
# Good data for vostok
# Processing Record 13 of Set 10 | kapit
# No rain
# No snow
# Good data for kapit
# Processing Record 14 of Set 10 | sacramento
# No rain
# No snow
# Good data for sacramento
# Processing Record 15 of Set 10 | broome
# No rain
# No snow
# Good data for broome
# Processing Record 16 of Set 10 | havoysund
# No rain
# No snow
# Good data for havoysund
# Processing Record 17 of Set 10 | beba
# No rain
# No snow
# Good data for beba
# Processing Record 18 of Set 10 | baykit
# No rain
# No snow
# Good data for baykit
# Processing Record 19 of Set 10 | ibiruba
# No rain
# No snow
# Good data for ibiruba
# Processing Record 20 of Set 10 | minnedosa
# No rain
# No snow
# Good data for minnedosa
# Processing Record 21 of Set 10 | vigrestad
# No snow
# Good data for vigrestad
# Processing Record 22 of Set 10 | nizza monferrato
# No rain
# No snow
# Good data for nizza monferrato
# Processing Record 23 of Set 10 | nokaneng
# No rain
# No snow
# Good data for nokaneng
# Processing Record 24 of Set 10 | san policarpo
# No snow
# Good data for san policarpo
# Processing Record 25 of Set 10 | dehloran
# No rain
# No snow
# Good data for dehloran
# Processing Record 26 of Set 10 | moyo
# No rain
# No snow
# Good data for moyo
# Processing Record 27 of Set 10 | minab
# No rain
# No snow
# Good data for minab
# Processing Record 28 of Set 10 | nova olinda do norte
# No rain
# No snow
# Good data for nova olinda do norte
# Processing Record 29 of Set 10 | isangel
# No rain
# No snow
# Good data for isangel
# Processing Record 30 of Set 10 | praya
# No rain
# No snow
# Good data for praya
# Processing Record 31 of Set 10 | kropotkin
# No rain
# No snow
# Good data for kropotkin
# Processing Record 32 of Set 10 | shiraoi
# No rain
# No snow
# Good data for shiraoi
# Processing Record 33 of Set 10 | mizan teferi
# No rain
# No snow
# Good data for mizan teferi
# Processing Record 34 of Set 10 | namibe
# No rain
# No snow
# Good data for namibe
# Processing Record 35 of Set 10 | kawalu
# No rain
# No snow
# Good data for kawalu
# Processing Record 36 of Set 10 | lucapa
# No rain
# No snow
# Good data for lucapa
# Processing Record 37 of Set 10 | roma
# No rain
# No snow
# Good data for roma
# Processing Record 38 of Set 10 | katha
# City not found. Skipping...
# Processing Record 39 of Set 10 | mormugao
# No snow
# Good data for mormugao
# Processing Record 40 of Set 10 | santa isabel do rio negro
# No snow
# Good data for santa isabel do rio negro
# Processing Record 41 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 42 of Set 10 | tuatapere
# No rain
# No snow
# Good data for tuatapere
# Processing Record 43 of Set 10 | yomou
# No rain
# No snow
# Good data for yomou
# Processing Record 44 of Set 10 | kloulklubed
# No rain
# No snow
# Good data for kloulklubed
# Processing Record 45 of Set 10 | olafsvik
# No rain
# No snow
# Good data for olafsvik
# Processing Record 46 of Set 10 | nova prata
# No snow
# Good data for nova prata
# Processing Record 47 of Set 10 | jasper
# No rain
# No snow
# Good data for jasper
# Processing Record 48 of Set 10 | nara
# No rain
# No snow
# Good data for nara
# Processing Record 49 of Set 10 | manicore
# No rain
# No snow
# Good data for manicore
# Processing Record 50 of Set 10 | playas
# No rain
# No snow
# Good data for playas
# Processing Record 1 of Set 11 | kapoeta
# No rain
# No snow
# Good data for kapoeta
# Processing Record 2 of Set 11 | phalodi
# No rain
# No snow
# Good data for phalodi
# Processing Record 3 of Set 11 | novoagansk
# No rain
# No snow
# Good data for novoagansk
# Processing Record 4 of Set 11 | oksfjord
# No snow
# Good data for oksfjord
# Processing Record 5 of Set 11 | alice springs
# No rain
# No snow
# Good data for alice springs
# Processing Record 6 of Set 11 | luau
# No rain
# No snow
# Good data for luau
# Processing Record 7 of Set 11 | verkhnevilyuysk
# No rain
# No snow
# Good data for verkhnevilyuysk
# Processing Record 8 of Set 11 | whitehorse
# No rain
# No snow
# Good data for whitehorse
# Processing Record 9 of Set 11 | ekhabi
# No rain
# No snow
# Good data for ekhabi
# Processing Record 10 of Set 11 | petropavlovsk-kamchatskiy
# No rain
# No snow
# Good data for petropavlovsk-kamchatskiy
# Processing Record 11 of Set 11 | bichura
# No rain
# No snow
# Good data for bichura
# Processing Record 12 of Set 11 | yenotayevka
# No rain
# No snow
# Good data for yenotayevka
# Processing Record 13 of Set 11 | sueyoshi
# No rain
# No snow
# Good data for sueyoshi
# Processing Record 14 of Set 11 | puerto leguizamo
# No snow
# Good data for puerto leguizamo
# Processing Record 15 of Set 11 | sammamish
# No rain
# No snow
# Good data for sammamish
# Processing Record 16 of Set 11 | kapuskasing
# No rain
# No snow
# Good data for kapuskasing
# Processing Record 17 of Set 11 | vogar
# No rain
# No snow
# Good data for vogar
# Processing Record 18 of Set 11 | riaba
# City not found. Skipping...
# Processing Record 19 of Set 11 | watrous
# No rain
# No snow
# Good data for watrous
# Processing Record 20 of Set 11 | karratha
# No rain
# No snow
# Good data for karratha
# Processing Record 21 of Set 11 | karasjok
# No rain
# No snow
# Good data for karasjok
# Processing Record 22 of Set 11 | ewa beach
# No rain
# No snow
# Good data for ewa beach
# Processing Record 23 of Set 11 | cairns
# No rain
# No snow
# Good data for cairns
# Processing Record 24 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 11 | mansa
# No snow
# Good data for mansa
# Processing Record 27 of Set 11 | linhares
# No rain
# No snow
# Good data for linhares
# Processing Record 28 of Set 11 | ojinaga
# No rain
# No snow
# Good data for ojinaga
# Processing Record 29 of Set 11 | novyy urengoy
# No snow
# Good data for novyy urengoy
# Processing Record 30 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 11 | kula
# No rain
# No snow
# Good data for kula
# Processing Record 32 of Set 11 | barabai
# No snow
# Good data for barabai
# Processing Record 33 of Set 11 | sheregesh
# No rain
# No snow
# Good data for sheregesh
# Processing Record 34 of Set 11 | haines junction
# No rain
# No snow
# Good data for haines junction
# Processing Record 35 of Set 11 | canchungo
# No rain
# No snow
# Good data for canchungo
# Processing Record 36 of Set 11 | narayanavanam
# No snow
# Good data for narayanavanam
# Processing Record 37 of Set 11 | areosa
# No rain
# No snow
# Good data for areosa
# Processing Record 38 of Set 11 | ponta delgada
# No rain
# No snow
# Good data for ponta delgada
# Processing Record 39 of Set 11 | bombay
# No rain
# No snow
# Good data for bombay
# Processing Record 40 of Set 11 | dukat
# No rain
# No snow
# Good data for dukat
# Processing Record 41 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 42 of Set 11 | inverness
# No snow
# Good data for inverness
# Processing Record 43 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 44 of Set 11 | ayolas
# No rain
# No snow
# Good data for ayolas
# Processing Record 45 of Set 11 | sorong
# No rain
# No snow
# Good data for sorong
# Processing Record 46 of Set 11 | hailey
# No rain
# No snow
# Good data for hailey
# Processing Record 47 of Set 11 | kusk
# City not found. Skipping...
# Processing Record 48 of Set 11 | thakurgaon
# No snow
# Good data for thakurgaon
# Processing Record 49 of Set 11 | texarkana
# No rain
# No snow
# Good data for texarkana
# Processing Record 50 of Set 11 | bonoua
# No rain
# No snow
# Good data for bonoua
# Processing Record 1 of Set 12 | zhangye
# No rain
# No snow
# Good data for zhangye
# Processing Record 2 of Set 12 | thunder bay
# No rain
# No snow
# Good data for thunder bay
# Processing Record 3 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 4 of Set 12 | klichka
# No rain
# No snow
# Good data for klichka
# Processing Record 5 of Set 12 | kamaishi
# No rain
# No snow
# Good data for kamaishi
# Processing Record 6 of Set 12 | westport
# No rain
# No snow
# Good data for westport
# Processing Record 7 of Set 12 | viedma
# No rain
# No snow
# Good data for viedma
# Processing Record 8 of Set 12 | chiredzi
# No rain
# No snow
# Good data for chiredzi
# Processing Record 9 of Set 12 | ngunguru
# No rain
# No snow
# Good data for ngunguru
# Processing Record 10 of Set 12 | lola
# No snow
# Good data for lola
# Processing Record 11 of Set 12 | freetown
# No snow
# Good data for freetown
# Processing Record 12 of Set 12 | kieta
# No snow
# Good data for kieta
# Processing Record 13 of Set 12 | antsohihy
# No rain
# No snow
# Good data for antsohihy
# Processing Record 14 of Set 12 | sao filipe
# No rain
# No snow
# Good data for sao filipe
# Processing Record 15 of Set 12 | walvis bay
# No rain
# No snow
# Good data for walvis bay
# Processing Record 16 of Set 12 | trairi
# No snow
# Good data for trairi
# Processing Record 17 of Set 12 | kalabo
# No rain
# No snow
# Good data for kalabo
# Processing Record 18 of Set 12 | bulawayo
# No rain
# No snow
# Good data for bulawayo
# Processing Record 19 of Set 12 | ajdabiya
# No rain
# No snow
# Good data for ajdabiya
# Processing Record 20 of Set 12 | bow island
# No rain
# No snow
# Good data for bow island
# Processing Record 21 of Set 12 | bowen
# No rain
# No snow
# Good data for bowen
# Processing Record 22 of Set 12 | roi et
# No snow
# Good data for roi et
# Processing Record 23 of Set 12 | alekseyevsk
# No rain
# No snow
# Good data for alekseyevsk
# Processing Record 24 of Set 12 | lerwick
# No rain
# No snow
# Good data for lerwick
# Processing Record 25 of Set 12 | dubti
# No rain
# No snow
# Good data for dubti
# Processing Record 26 of Set 12 | yeppoon
# No rain
# No snow
# Good data for yeppoon
# Processing Record 27 of Set 12 | meadow lake
# No rain
# No snow
# Good data for meadow lake
# Processing Record 28 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 29 of Set 12 | vicosa
# No rain
# No snow
# Good data for vicosa
# Processing Record 30 of Set 12 | basco
# No snow
# Good data for basco
# Processing Record 31 of Set 12 | dhidhdhoo
# No snow
# Good data for dhidhdhoo
# Processing Record 32 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 34 of Set 12 | port macquarie
# No rain
# No snow
# Good data for port macquarie
# Processing Record 35 of Set 12 | phek
# No rain
# No snow
# Good data for phek
# Processing Record 36 of Set 12 | puri
# No rain
# No snow
# Good data for puri
# Processing Record 37 of Set 12 | toccoa
# No rain
# No snow
# Good data for toccoa
# Processing Record 38 of Set 12 | nanyuki
# No rain
# No snow
# Good data for nanyuki
# Processing Record 39 of Set 12 | asyut
# No rain
# No snow
# Good data for asyut
# Processing Record 40 of Set 12 | yuci
# No rain
# No snow
# Good data for yuci
# Processing Record 41 of Set 12 | aracuai
# No rain
# No snow
# Good data for aracuai
# Processing Record 42 of Set 12 | zlitan
# No rain
# No snow
# Good data for zlitan
# Processing Record 43 of Set 12 | stepnyak
# No rain
# No snow
# Good data for stepnyak
# Processing Record 44 of Set 12 | mogok
# No snow
# Good data for mogok
# Processing Record 45 of Set 12 | champerico
# No rain
# No snow
# Good data for champerico
# Processing Record 46 of Set 12 | big spring
# No rain
# No snow
# Good data for big spring
# Processing Record 47 of Set 12 | rosarito
# No rain
# No snow
# Good data for rosarito
# Processing Record 48 of Set 12 | derzhavinsk
# No rain
# No snow
# Good data for derzhavinsk
# Processing Record 49 of Set 12 | flin flon
# No rain
# No snow
# Good data for flin flon
# Processing Record 50 of Set 12 | marsh harbour
# No rain
# No snow
# Good data for marsh harbour
# Processing Record 1 of Set 13 | avera
# No rain
# No snow
# Good data for avera
# Processing Record 2 of Set 13 | tilichiki
# No rain
# No snow
# Good data for tilichiki
# Processing Record 3 of Set 13 | idil
# No rain
# No snow
# Good data for idil
# Processing Record 4 of Set 13 | nantucket
# No rain
# No snow
# Good data for nantucket
# Processing Record 5 of Set 13 | kenai
# No snow
# Good data for kenai
# Processing Record 6 of Set 13 | aden
# No rain
# No snow
# Good data for aden
# Processing Record 7 of Set 13 | forbes
# No rain
# No snow
# Good data for forbes
# Processing Record 8 of Set 13 | tabuk
# No rain
# No snow
# Good data for tabuk
# Processing Record 9 of Set 13 | vyara
# No rain
# No snow
# Good data for vyara
# Processing Record 10 of Set 13 | sangar
# No rain
# No snow
# Good data for sangar
# Processing Record 11 of Set 13 | port hardy
# No rain
# No snow
# Good data for port hardy
# Processing Record 12 of Set 13 | tiarei
# No rain
# No snow
# Good data for tiarei
# Processing Record 13 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 14 of Set 13 | gayny
# No rain
# No snow
# Good data for gayny
# Processing Record 15 of Set 13 | aksu
# No rain
# No snow
# Good data for aksu
# Processing Record 16 of Set 13 | grand gaube
# No snow
# Good data for grand gaube
# Processing Record 17 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 18 of Set 13 | wiarton
# No rain
# No snow
# Good data for wiarton
# Processing Record 19 of Set 13 | yerofey pavlovich
# No rain
# No snow
# Good data for yerofey pavlovich
# Processing Record 20 of Set 13 | iskateley
# No rain
# No snow
# Good data for iskateley
# Processing Record 21 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 22 of Set 13 | laredo
# No rain
# No snow
# Good data for laredo
# Processing Record 23 of Set 13 | conakry
# No snow
# Good data for conakry
# Processing Record 24 of Set 13 | oum hadjer
# No rain
# No snow
# Good data for oum hadjer
# Processing Record 25 of Set 13 | arman
# No rain
# No snow
# Good data for arman
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City    Lat     Lng  Max Temp  Humidity  Wind Speed Country  \
# 0             Lagoa  39.05  -27.98     68.83        78       16.42      PT
# 1             Muros  42.78   -9.06     73.99        64       13.00      ES
# 2          Ahuimanu  21.44 -157.84     84.20        48       16.11      US
# 3       Tuktoyaktuk  69.45 -133.04     57.20        67        9.17      CA
# 4    Saint-Augustin  51.23  -58.65     62.01        95       14.85      CA
# ..              ...    ...     ...       ...       ...         ...     ...
# 564       Iskateley  67.68   53.15     45.50        89       14.20      RU
# 565          Laredo  27.51  -99.51    102.20        35        9.17      US
# 566         Conakry   9.54  -13.68     77.29        88       13.44      GN
# 567      Oum Hadjer  13.30   19.70     88.95        42        6.15      TD
# 568           Arman  59.70  150.17     61.59        73        2.33      RU
#
#          Current Desc  Rain  Snow
# 0           clear sky  0.00     0
# 1           clear sky  0.00     0
# 2       broken clouds  0.00     0
# 3    scattered clouds  0.00     0
# 4     overcast clouds  0.00     0
# ..                ...   ...   ...
# 564   overcast clouds  0.00     0
# 565         clear sky  0.00     0
# 566     moderate rain  2.75     0
# 567         clear sky  0.00     0
# 568         clear sky  0.00     0
#
# [569 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
